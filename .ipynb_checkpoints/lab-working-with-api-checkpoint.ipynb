# %%
import json
import requests
import pandas as pd

# %%
response = requests.get('https://api.instagram.com/v1/locations/{location-id}')

data = pd.DataFrame(response.json())
data.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-cdb7109357f8> in <module>
#       1 response = requests.get('https://api.instagram.com/v1/locations/{location-id}')
#       2
# ----> 3 data = pd.DataFrame(response.json())
#       4 data.head()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
# ...

# %%
response = requests.get('http://hp-api.herokuapp.com/api/characters')

data = pd.DataFrame(response.json())
data.head()
# Out:
#                  name alternate_names species  gender       house dateOfBirth  \
# 0        Harry Potter              []   human    male  Gryffindor  31-07-1980
# 1    Hermione Granger              []   human  female  Gryffindor  19-09-1979
# 2         Ron Weasley              []   human    male  Gryffindor  01-03-1980
# 3        Draco Malfoy              []   human    male   Slytherin  05-06-1980
# 4  Minerva McGonagall              []   human  female  Gryffindor  04-10-1925
#
#   yearOfBirth  wizard    ancestry eyeColour hairColour  \
# 0        1980    True  half-blood     green      black
# 1        1979    True  muggleborn     brown      brown
# 2        1980    True  pure-blood      blue        red
# 3        1980    True  pure-blood      grey     blonde
# 4        1925    True                            black
#
#                                                 wand              patronus  \
# 0  {'wood': 'holly', 'core': 'phoenix feather', '...                  stag
# ...

# %%
from pandas.io.json import json_normalize
results = response.json()
flattened_data = json_normalize(results)
flattened_data
# Out:
# <ipython-input-9-92e1e1bf2b5a>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#                    name alternate_names species  gender       house  \
# 0          Harry Potter              []   human    male  Gryffindor
# 1      Hermione Granger              []   human  female  Gryffindor
# 2           Ron Weasley              []   human    male  Gryffindor
# 3          Draco Malfoy              []   human    male   Slytherin
# 4    Minerva McGonagall              []   human  female  Gryffindor
# ..                  ...             ...     ...     ...         ...
# 286            Summerby              []   human    male  Hufflepuff
# 287       Theodore Nott              []   human    male   Slythetin
# 288  Marietta Edgecombe              []   human  female   Ravenclaw
# 289     Madam Edgecombe              []   human  female
# 290        John Dawlish              []   human    male
#
# ...

# %%
response = requests.get('https://namo-memes.herokuapp.com/memes/latest/:n')

data = pd.DataFrame(response.json())
data.head()
# Out:
#                         _id  \
# 0  5d857bbc3d09e61ff99fd10b
# 1  5d857ac33d09e61ff99fd0bc
# 2  5d857ac33d09e61ff99fd0bb
# 3  5d857a173d09e61ff99fd07f
# 4  5d85770c3d09e61ff99fcf8f
#
#                                                  url  __v  \
# 0  https://scontent-lga3-1.cdninstagram.com/vp/fc...    0
# 1  https://static.asianetnews.com/images/01db393g...    0
# 2  https://ytimg.googleusercontent.com/vi/wefCKNn...    0
# 3  https://scontent-frx5-1.cdninstagram.com/v/t51...    0
# 4  https://ytimg.googleusercontent.com/vi/VD9CJuW...    0
#
#                   createdAt                 updatedAt
# 0  2019-09-21T01:24:12.281Z  2019-09-21T01:24:12.282Z
# 1  2019-09-21T01:20:03.559Z  2019-09-21T01:20:03.559Z
# 2  2019-09-21T01:20:03.558Z  2019-09-21T01:20:03.558Z
# 3  2019-09-21T01:17:11.200Z  2019-09-21T01:17:11.200Z
# 4  2019-09-21T01:04:12.185Z  2019-09-21T01:04:12.185Z

# %%
response = requests.get('https://www.breakingbadapi.com/api/characters')

data = pd.DataFrame(response.json())
data.head()
# Out:
#    char_id              name    birthday  \
# 0        1      Walter White  09-07-1958
# 1        2     Jesse Pinkman  09-24-1984
# 2        3      Skyler White  08-11-1970
# 3        4  Walter White Jr.  07-08-1993
# 4        5    Henry Schrader     Unknown
#
#                                           occupation  \
# 0     [High School Chemistry Teacher, Meth King Pin]
# 1                                      [Meth Dealer]
# 2  [House wife, Book Keeper, Car Wash Manager, Ta...
# 3                                         [Teenager]
# 4                                        [DEA Agent]
#
#                                                  img         status  \
# 0  https://images.amcnetworks.com/amc.com/wp-cont...  Presumed dead
# 1  https://vignette.wikia.nocookie.net/breakingba...          Alive
# 2  https://s-i.huffpost.com/gen/1317262/images/o-...          Alive
# 3  https://media1.popsugar-assets.com/files/thumb...          Alive
# ...
